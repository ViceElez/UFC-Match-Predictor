# %%
import pandas as pd

# %%
fights=pd.read_csv("data.csv")

# %%
fights.head()
# Out:
#           RedFighter        BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 0  Alexandre Pantoja        Kai Asakura   -250.0     215.0           40.0000
# 1  Shavkat Rakhmonov  Ian Machado Garry   -210.0     295.0           47.6190
# 2         Ciryl Gane   Alexander Volkov   -380.0     300.0           26.3158
# 3     Bryce Mitchell        Kron Gracie   -950.0     625.0           10.5263
# 4      Nate Landwehr         Dooho Choi   -130.0     110.0           76.9231
#
#    BlueExpectedValue        Date                Location Country Winner  ...  \
# 0              215.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 1              295.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 2              300.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 3              625.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 4              110.0  2024-12-07  Las Vegas, Nevada, USA     USA   Blue  ...
#
# ...

# %%
fights.shape
# Out:
# (6528, 118)

# %%
fights["RedFighter"].value_counts()
# Out:
# RedFighter
# Jim Miller        29
# Donald Cerrone    24
# Neil Magny        23
# Derrick Lewis     22
# Dustin Poirier    22
#                   ..
# John Gunderson     1
# Jamie Yager        1
# Keith Jardine      1
# Forrest Petz       1
# Chris Lytle        1
# Name: count, Length: 1661, dtype: int64

# %%
fights[fights["RedFighter"]=="Conor McGregor"]
# Out:
#           RedFighter     BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 2444  Conor McGregor  Donald Cerrone   -305.0     275.0           32.7869
# 4269  Conor McGregor       Nate Diaz   -425.0     340.0           23.5294
# 4798  Conor McGregor    Dennis Siver   -975.0     775.0           10.2564
# 5035  Conor McGregor   Diego Brandao   -690.0     560.0           14.4928
# 5477  Conor McGregor    Max Holloway   -245.0     225.0           40.8163
#
#       BlueExpectedValue        Date                    Location   Country  \
# 2444              275.0  2020-01-18      Las Vegas, Nevada, USA       USA
# 4269              340.0  2016-03-05      Las Vegas, Nevada, USA       USA
# 4798              775.0  2015-01-18  Boston, Massachusetts, USA       USA
# 5035              560.0  2014-07-19   Dublin, Leinster, Ireland   Ireland
# 5477              225.0  2013-08-17  Boston, Massachusetts, USA       USA
#
#      Winner  ...     FinishDetails FinishRound FinishRoundTime  \
# ...
